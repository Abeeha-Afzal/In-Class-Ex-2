# %%
2. Write code to create a class called Time that has separate member data for hours, minutes,
and seconds. Make constructor to initialize these attributes, with 0 being the default value.
Add the following methods:
 printTime( ): displays time in 11:59:59 format.
 addTime(t): takes one argument t of Time type and adds this time to the current time
of the self object.
a. Instantiate two objects t1 and t2 to any arbitrary values, display both the objects, add
t2 to t1 and display the result.
b. Format the output to print hours, minutes and seconds each in exactly two-digit space;
for example: 02:04:30

# %%
class Time:
    def __init__(self, hours=0, minutes=0, seconds=0):
        self.hours = hours
        self.minutes = minutes
        self.seconds = seconds

    def display(self):
        print(self.hours,':',self.minutes,':',self.seconds)
        
    def addTime(self,t):
        sec = self.seconds + t.seconds
        if sec > 60:
            self.minutes = self.minutes + 1
            rem_sec = sec - 60
        minute = self.minutes + t.minutes
        if minute > 60:
            self.hours = self.hours + 1
            rem_min = minute - 60
        hours = self.hours + t.hours
        print(hours, ':' ,rem_min, ':' ,rem_sec)

# %%
t1=Time(4,56,56)

# %%
t1.display()
# Out:
# 4 : 56 : 56

# %%
t2=Time(5,62,26)

# %%
t2.display()
# Out:
# 5 : 62 : 26

# %%
t2.addTime(t1)
# Out:
# 10 : 59 : 22
