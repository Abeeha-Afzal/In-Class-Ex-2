# %%
# TABLES

for i in range(1,11):
    result= 2 * i
    print(f"2 *{i} = {result}")
# Out:
# 2 *1 = 2
# 2 *2 = 4
# 2 *3 = 6
# 2 *4 = 8
# 2 *5 = 10
# 2 *6 = 12
# 2 *7 = 14
# 2 *8 = 16
# 2 *9 = 18
# 2 *10 = 20

# %%
for i in range(1,11):
    result = 10 * i
    print(f"10 * {i} = {result}")
# Out:
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100

# %%
my_list = [2,8,6,7,9,45]
my_list.sort()
my_list
# Out:
# [2, 6, 7, 8, 9, 45]

# %%
my_list.reverse()

# %%
my_list
# Out:
# [45, 9, 8, 7, 6, 2]

# %%
my_list.insert(2,78)
my_list
# Out:
# [45, 9, 78, 8, 7, 6, 2]

# %%
my_list [3] = 90
my_list
# Out:
# [45, 9, 78, 90, 7, 6, 2]

# %%
del(my_list[5])
my_list
# Out:
# [45, 9, 78, 90, 7, 2]

# %%
value = input("Enter a value")
value
# Out:
# 'hello world'

# %%
num1 = 34
num2 = 34
result = num1 + num2
result
# Out:
# 68

# %%
num1 = int(input("Enter number 1: "))
print(type(num1))
num2 = int(input("Enter number 2: "))
print(type(num2))
add = num1 + num2
add
# Out:
# <class 'int'>
# <class 'int'>
# 7

# %%
fruits = input("Enter 3 fruits: ")
print(fruits)
print(type(fruits))
print(list(fruits))
# Out:
# mango,banana,apricot
# <class 'str'>
# ['m', 'a', 'n', 'g', 'o', ',', 'b', 'a', 'n', 'a', 'n', 'a', ',', 'a', 'p', 'r', 'i', 'c', 'o', 't']
