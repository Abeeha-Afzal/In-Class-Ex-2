# %%
import pandas as pd # Library 
# To install it go on a command prompt and

# %%
my_series = pd.Series([23,56,78,89])

# %%
my_series
# Out:
# 0    23
# 1    56
# 2    78
# 3    89
# dtype: int64

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
my_data_frame = pd.DataFrame({'age':[22,45,67,78],'height': [78,34,22,9]})

# %%
my_data_frame
# Out:
#    age  height
# 0   22      78
# 1   45      34
# 2   67      22
# 3   78       9

# %%
my_data_frame.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
my_data_frame.iloc[1:4 ,0:2] # used when indexes are in integer form [start: end -1]
# Out:
#    age  height
# 1   45      34
# 2   67      22
# 3   78       9

# %%
names = pd.Series(['Safa','Abeeha','Pandas'], index=['a','b','c'])

# %%
names
# Out:
# a      Safa
# b    Abeeha
# c    Pandas
# dtype: object

# %%
names.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
student = {'name':['Abeeha','Rehman','Ramsha'], 'age':[16,15,22]}
my_student = pd.DataFrame(student,index =["a","b","c"])

# %%
my_student
# Out:
#      name  age
# a  Abeeha   16
# b  Rehman   15
# c  Ramsha   22

# %%
columns_name ={
    'name': 'Full Name' ,
    'age': 'Std_age'
}
my_student.rename(columns = columns_name , inplace = True)

# %%
my_student
# Out:
#   Full Name  Std_age
# a    Abeeha       16
# b    Rehman       15
# c    Ramsha       22

# %%
my_student.columns
# Out:
# Index(['Full Name', 'Std_age'], dtype='object')

# %%
my_student.loc['a'] # use when index is in a texted form
# Out:
# Full Name    Abeeha
# Std_age          16
# Name: a, dtype: object

# %%
book = {'Book Name':["Harry Potter and the Philospher's Stone","Charlie and the chocolate factory","Famous Five"], 'Author Name':["Jk Rowling","Roald Dahl","Enid Blyton"],'Price':[3000,2000,1550],'Year':[1997,1964,1942]}
my_book = pd.DataFrame(book,index=['>1','>2','>3'])

# %%
my_book
# Out:
#                                   Book Name  Author Name  Price  Year
# >1  Harry Potter and the Philospher's Stone   Jk Rowling   3000  1997
# >2        Charlie and the chocolate factory   Roald Dahl   2000  1964
# >3                              Famous Five  Enid Blyton   1550  1942

# %%
my_book.columns
# Out:
# Index(['Book Name', 'Author Name', 'Price', 'Year'], dtype='object')

# %%
names['b']
# Out:
# 'Abeeha'

# %%
my_series[2]
# Out:
# 78

# %%
my_student.loc['a':'c']
# Out:
#   Full Name  Std_age
# a    Abeeha       16
# b    Rehman       15
# c    Ramsha       22

# %%
my_book['Author Name']
# Out:
# >1     Jk Rowling
# >2     Roald Dahl
# >3    Enid Blyton
# Name: Author Name, dtype: object

# %%
books_data = pd.read_csv('Book 1.csv')
books_data
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
books_data.loc[50]
# Out:
# Film                 Life as We Know It
# Genre                            Comedy
# Lead Studio                 Independent
# Audience score %                     62
# Profitability                  2.530526
# Rotten Tomatoes %                    28
# Worldwide Gross                 $96.16
# Year                               2010
# Name: 50, dtype: object

# %% [markdown]
# Data preprocessing:
# 1 -> Data load
# 2 -> Columns
# 3 -> Data Cleaning
# A -> Remove Duplicates
# B -> Null Values Handling
# C -> NaN Values Handling
# D -> Removal of rows and columns
# E -> Feature Engineering
# In DataScience columns are known as "FEATURE".
# 4 -> Data Visualization
# s -> Data Analysis
#
# # Data Analyst
# # Machine Learning
# # Data scientist
