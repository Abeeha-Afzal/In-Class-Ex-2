# %%
# Polymorphism
# Inheritance
# Composition
# Aggregation
# Association
# Abstarction

# %%
# Inheritance:
# 1) All methods and attributes of present class will transfer into child classes.

# %%
# Parent
class Shapes:
    def __init__(self,color,sides):
        self.color = color
        self.sides = sides
    def getter(self):
        print('Color: ', self.color)
        print('Sides: ', self.sides)

# %%
# Child
class Square(Shapes):
    def __init__(self,color,length,height):
        self.length = length
        self.height = height
        super().__init__(color,4)
    def getter(self): #method overriding
        print("Color: ",self.color)
        print("Sides:",self.sides)
        print("Length: ",self.length)
        print("Height: ",self.height)
    def area(self):
        print("Area of square:",self.length *2)

# %%
class Rectangle(Shapes):
    def __init__(self,color,length,height):
        self.length = length
        self.height = height
        super().__init__(color,4)
    def getter(self): #method overriding
        print("Color: ",self.color)
        print("Sides:",self.sides)
        print("Length: ",self.length)
        print("Height: ",self.height)
    def area(self):
        print("Area of rectangle:",self.length * self.height)

# %%
class Hexagon(Shapes):
    def __init__(self,color,length,height):
        self.length = length
        self.height = height
        super().__init__(color,6)
    def getter(self): #method overriding
        print("Color: ",self.color)
        print("Sides:",self.sides)
        print("Length: ",self.length)
        print("Height: ",self.height)
    def area(self):
        print("Area of Hexagon:", (3 * (3 ** 0.5) / 2) * self.sides** 2)

# %%
hexagon = Hexagon('Yellow',2,7)
hexagon.getter()
# Out:
# Color:  Yellow
# Sides: 6
# Length:  2
# Height:  7

# %%
hexagon.area()
# Out:
# Area of Hexagon: 93.53074360871938

# %%
rectangle = Rectangle('Red',5,7)
rectangle.getter()
# Out:
# Color:  Red
# Sides: 4
# Length:  5
# Height:  7

# %%
rectangle.area()
# Out:
# Area of rectangle: 35

# %%
shape = Shapes('Blue',4)
shape.getter()
# Out:
# Color:  Blue
# Sides:  4

# %%
sq2 = Square('Orange',3,7)
sq2.getter()
# Out:
# Color:  Orange
# Sides: 4
# Length:  3
# Height:  7

# %%
sq2.area()
# Out:
# Area of square: 6

# %%
square = Square('Pink',4,8)
square.getter()
# Out:
# Color:  Pink
# Sides: 4
# Length:  4
# Height:  8

# %%
# Parent class
class Animal:
    def __init__(self,no_of_legs,tail):
        self.no_of_legs= no_of_legs
        self.tail = tail
        
    def sound(self,sound):
        self.sound = sound
        #print("Sound of animal:",self.sound)

# %%
# Child class
class Lion(Animal): # Concrete class
    def __init__(self,color,no_of_legs,tail,age,sound):
        self.color = color
        self.age = age
        self.sound = sound
        super().__init__(no_of_legs,tail)
    
    def getter(self):
        print('Legs:', self.no_of_legs)
        print('sound:',self.sound)
        print('color:',self.color)
        print('tail:',self.tail)

# %%
Lion1 = Lion('Brown',4, True,2,'roar')
Lion1.getter()
# Out:
# Legs: 4
# sound: roar
# color: Brown
# tail: True

# %%
class Elephant(Animal):
    def __init__(self,color,no_of_legs,tail,age,trunk_length):
        self.color = color
        self.age = age
        self.trunk_length = trunk_length
        
        super().__init__(no_of_legs,tail)
    
    def getter(self):
        print('Legs:', self.no_of_legs)
        print('sound:',self.sound)
        print('color:',self.color)
        print('tail:',self.tail)
        print('Trunk Length:',self.trunk_length)

# %%
Elephant1 = Elephant('Grey',4,True,3,2.5)
Elephant1.getter()
# Out:
# Legs: 4
# sound: <bound method Animal.sound of <__main__.Elephant object at 0x0000025C7F904AF0>>
# color: Grey
# tail: True
# Trunk Length: 2.5

# %%
# Method Overloading
class Vector:
    def __init__(self,x):
        self.x = x
    def hello(self): # Abstract code
        pass
        
    def __add__(self,v):
        print("Hello",self.x,num2.x)

# %%
num1 = Vector(2)
num2 = Vector(3)
num1 + num2
# Out:
# Hello 2 3

# %%
# Abstract class
class Mobile:
   # color = "black" # public
   # _size = 23 # protected
    # __model = 897 # private
    def __init__(self,color,size,model):
        self.color=color # public
        self._size = size # protected 
        self.__model = model # private
    @classmethod
    def hello(cls):
        print(123)
    #def hello(self): # public
        #print(123)
    def _get(self): # protected
        print(345)
    def __set(self): #Private
        print(789)

# %%
mob1 = Mobile('white',20,527)
Mobile.hello()
mob1.color
# Out:
# 123
# 'white'

# %%
mob1._size
# Out:
# 20

# %%
mob1.__model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 mob1.__model
#
# AttributeError: 'Mobile' object has no attribute '__model'

# %%
class Samsung_A21(Mobile):
